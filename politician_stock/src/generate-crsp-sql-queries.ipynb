# %% [markdown]
# # Generate WRDS CRSP SQL Queries

# %%
import numpy as np
import pandas as pd

from datetime import datetime

# %%
DATA_PATH = "../data/"

# %% [markdown]
# ## Senate

# %%
senate = pd.read_csv(DATA_PATH + "senate_all_transactions.csv")
senate[:5]
# Out:
#   transaction_date   owner ticker  \
# 0       08/10/2022  Spouse     --
# 1       08/01/2022    Self    IVV
# 2       08/01/2022    Self   EFAV
# 3       08/01/2022    Self    XLY
# 4       08/01/2022    Self   VTRS
#
#                                    asset_description      asset_type  \
# 0  Parker-Hannifin Corp 701094AQ7 <div class="tex...  Corporate Bond
# 1                       iShares Core S&amp;P 500 ETF           Stock
# 2               iShares MSCI EAFE Min Vol Factor ETF           Stock
# 3   SPDR Select Sector Fund - Consumer Discretionary           Stock
# 4                        Viatris Inc. - Common Stock           Stock
#
#           type             amount comment              senator  \
# 0     Purchase  $15,001 - $50,000      --      Susan M Collins
# 1  Sale (Full)  $15,001 - $50,000      --  Thomas H Tuberville
# 2  Sale (Full)  $15,001 - $50,000      --  Thomas H Tuberville
# 3  Sale (Full)  $15,001 - $50,000      --  Thomas H Tuberville
# 4  Sale (Full)   $1,001 - $15,000      --  Thomas H Tuberville
#
#                                             ptr_link disclosure_date
# 0  https://efdsearch.senate.gov/search/view/ptr/7...      09/16/2022
# 1  https://efdsearch.senate.gov/search/view/ptr/7...      09/15/2022
# 2  https://efdsearch.senate.gov/search/view/ptr/7...      09/15/2022
# 3  https://efdsearch.senate.gov/search/view/ptr/7...      09/15/2022
# 4  https://efdsearch.senate.gov/search/view/ptr/7...      09/15/2022

# %%
senate_dt_tic = senate[["transaction_date", "ticker"]].copy()

date_q = list(map(lambda x: datetime.strptime(x, '%m/%d/%Y').strftime("%Y-%m-%d"), senate_dt_tic["transaction_date"]))
ticker_q = senate_dt_tic["ticker"].replace("--", np.nan)

senate_dt_tic["date_q"] = date_q
senate_dt_tic["ticker_q"] = ticker_q

senate_dt_tic
# Out:
#      transaction_date ticker      date_q ticker_q
# 0          08/10/2022     --  2022-08-10      NaN
# 1          08/01/2022    IVV  2022-08-01      IVV
# 2          08/01/2022   EFAV  2022-08-01     EFAV
# 3          08/01/2022    XLY  2022-08-01      XLY
# 4          08/01/2022   VTRS  2022-08-01     VTRS
# ...               ...    ...         ...      ...
# 9548       08/17/2012    NaN  2012-08-17      NaN
# 9549       08/16/2012    NaN  2012-08-16      NaN
# 9550       08/15/2012    NaN  2012-08-15      NaN
# 9551       08/02/2012    NaN  2012-08-02      NaN
# 9552       07/25/2012    NaN  2012-07-25      NaN
#
# [9553 rows x 4 columns]

# %%
senate_dt_tic_grouped = pd.DataFrame(senate_dt_tic.groupby("ticker_q")["date_q"].apply(list))
senate_dt_tic_grouped["date_q_str"] = senate_dt_tic_grouped["date_q"].astype(str).str.replace("[", "(", regex=False)
senate_dt_tic_grouped["date_q_str"] = senate_dt_tic_grouped["date_q_str"].str.replace("]", ")", regex=False)
senate_dt_tic_grouped = senate_dt_tic_grouped.reset_index()
senate_dt_tic_grouped
# Out:
#      ticker_q                                             date_q  \
# 0     0QZI.IL                           [2019-09-25, 2019-09-25]
# 1     3V64.TI                           [2019-09-25, 2019-09-25]
# 2           A   [2016-09-13, 2015-08-24, 2015-02-24, 2014-10-02]
# 3          AA  [2021-10-18, 2021-10-15, 2021-07-29, 2021-07-1...
# 4       AAGIY                                       [2019-03-11]
# ...       ...                                                ...
# 1169     ZNGA   [2016-12-15, 2016-04-20, 2015-01-16, 2014-11-07]
# 1170  ZNGA.SW                                       [2017-07-14]
# 1171      ZTS               [2015-01-14, 2015-01-29, 2015-01-30]
# 1172     ^MWE                                       [2015-12-04]
# 1173     ^RGP                                       [2015-05-01]
#
#                                              date_q_str
# 0                          ('2019-09-25', '2019-09-25')
# 1                          ('2019-09-25', '2019-09-25')
# 2     ('2016-09-13', '2015-08-24', '2015-02-24', '20...
# 3     ('2021-10-18', '2021-10-15', '2021-07-29', '20...
# 4                                        ('2019-03-11')
# ...                                                 ...
# 1169  ('2016-12-15', '2016-04-20', '2015-01-16', '20...
# 1170                                     ('2017-07-14')
# 1171         ('2015-01-14', '2015-01-29', '2015-01-30')
# 1172                                     ('2015-12-04')
# 1173                                     ('2015-05-01')
#
# [1174 rows x 3 columns]

# %%
def generate_sql_queries(ticker, date_tuple):
    return f"SELECT * FROM crsp.wrds_dsfv2_query WHERE ticker='{ticker}' AND dlycaldt IN {date_tuple};"
v_generate_sql_queries = np.vectorize(generate_sql_queries)

# %%
senate_dt_tic_grouped["sql"] = v_generate_sql_queries(senate_dt_tic_grouped["ticker_q"], senate_dt_tic_grouped["date_q_str"])
senate_dt_tic_grouped
# Out:
#      ticker_q                                             date_q  \
# 0     0QZI.IL                           [2019-09-25, 2019-09-25]
# 1     3V64.TI                           [2019-09-25, 2019-09-25]
# 2           A   [2016-09-13, 2015-08-24, 2015-02-24, 2014-10-02]
# 3          AA  [2021-10-18, 2021-10-15, 2021-07-29, 2021-07-1...
# 4       AAGIY                                       [2019-03-11]
# ...       ...                                                ...
# 1169     ZNGA   [2016-12-15, 2016-04-20, 2015-01-16, 2014-11-07]
# 1170  ZNGA.SW                                       [2017-07-14]
# 1171      ZTS               [2015-01-14, 2015-01-29, 2015-01-30]
# 1172     ^MWE                                       [2015-12-04]
# 1173     ^RGP                                       [2015-05-01]
#
#                                              date_q_str  \
# 0                          ('2019-09-25', '2019-09-25')
# 1                          ('2019-09-25', '2019-09-25')
# 2     ('2016-09-13', '2015-08-24', '2015-02-24', '20...
# 3     ('2021-10-18', '2021-10-15', '2021-07-29', '20...
# 4                                        ('2019-03-11')
# ...                                                 ...
# 1169  ('2016-12-15', '2016-04-20', '2015-01-16', '20...
# 1170                                     ('2017-07-14')
# 1171         ('2015-01-14', '2015-01-29', '2015-01-30')
# 1172                                     ('2015-12-04')
# 1173                                     ('2015-05-01')
#
#                                                     sql
# 0     SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 1     SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 2     SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 3     SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 4     SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# ...                                                 ...
# 1169  SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 1170  SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 1171  SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 1172  SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 1173  SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
#
# [1174 rows x 4 columns]

# %%
# test
senate_dt_tic_grouped[senate_dt_tic_grouped["ticker_q"]=="IVV"]["sql"].iloc[0]
# Out:
# "SELECT * FROM crsp.wrds_dsfv2_query WHERE ticker='IVV' AND dlycaldt IN ('2022-08-01', '2022-08-10', '2022-05-10', '2021-07-26', '2020-04-02');"

# %%
output = senate_dt_tic_grouped[["ticker_q", "sql"]].copy()
output.to_csv("senate_sql_queries.csv", index=False)

# %% [markdown]
# ## House

# %%
house = pd.read_csv(DATA_PATH + "house_all_transactions_fixed.csv")
house[:5]
# Out:
#    disclosure_year disclosure_date transaction_date  owner ticker  \
# 0             2021      10/04/2021       2021-09-27  joint     BP
# 1             2021      10/04/2021       2021-09-13  joint    XOM
# 2             2021      10/04/2021       2021-09-10  joint   ILPT
# 3             2021      10/04/2021       2021-09-28  joint     PM
# 4             2021      10/04/2021       2021-09-17   self    BLK
#
#                                    asset_description          type  \
# 0                                             BP plc      purchase
# 1                            Exxon Mobil Corporation      purchase
# 2  Industrial Logistics Properties Trust - Common...      purchase
# 3                   Phillip Morris International Inc      purchase
# 4                                      BlackRock Inc  sale_partial
#
#               amount          representative district  \
# 0   $1,001 - $15,000      Hon. Virginia Foxx     NC05
# 1   $1,001 - $15,000      Hon. Virginia Foxx     NC05
# 2  $15,001 - $50,000      Hon. Virginia Foxx     NC05
# 3  $15,001 - $50,000      Hon. Virginia Foxx     NC05
# 4   $1,001 - $15,000  Hon. Alan S. Lowenthal     CA47
#
#                                             ptr_link  cap_gains_over_200_usd
# 0  https://disclosures-clerk.house.gov/public_dis...                   False
# 1  https://disclosures-clerk.house.gov/public_dis...                   False
# 2  https://disclosures-clerk.house.gov/public_dis...                   False
# 3  https://disclosures-clerk.house.gov/public_dis...                   False
# 4  https://disclosures-clerk.house.gov/public_dis...                   False

# %%
house_dt_tic = house[["transaction_date", "ticker"]].copy()

date_q = list(map(lambda x: datetime.strptime(x, "%Y-%m-%d").strftime("%Y-%m-%d"), house_dt_tic["transaction_date"]))
ticker_q = house_dt_tic["ticker"].replace("--", np.nan)

house_dt_tic["date_q"] = date_q
house_dt_tic["ticker_q"] = ticker_q

house_dt_tic
# Out:
#       transaction_date ticker      date_q ticker_q
# 0           2021-09-27     BP  2021-09-27       BP
# 1           2021-09-13    XOM  2021-09-13      XOM
# 2           2021-09-10   ILPT  2021-09-10     ILPT
# 3           2021-09-28     PM  2021-09-28       PM
# 4           2021-09-17    BLK  2021-09-17      BLK
# ...                ...    ...         ...      ...
# 15427       2020-04-09    SWK  2020-04-09      SWK
# 15428       2020-04-09    USB  2020-04-09      USB
# 15429       2020-03-13    BMY  2020-03-13      BMY
# 15430       2020-03-13    LLY  2020-03-13      LLY
# 15431       2020-03-13    DIS  2020-03-13      DIS
#
# [15432 rows x 4 columns]

# %%
house_dt_tic_grouped = pd.DataFrame(house_dt_tic.groupby("ticker_q")["date_q"].apply(list))
house_dt_tic_grouped["date_q_str"] = house_dt_tic_grouped["date_q"].astype(str).str.replace("[", "(", regex=False)
house_dt_tic_grouped["date_q_str"] = house_dt_tic_grouped["date_q_str"].str.replace("]", ")", regex=False)
house_dt_tic_grouped = house_dt_tic_grouped.reset_index()
house_dt_tic_grouped
# Out:
#      ticker_q                                             date_q  \
# 0      35G.SG                           [2021-02-26, 2021-02-26]
# 1         7XY                                       [2021-11-19]
# 2           A               [2021-02-16, 2020-04-09, 2021-11-18]
# 3          AA  [2020-11-17, 2019-12-18, 2022-08-02, 2022-08-0...
# 4       AAGIY  [2021-02-17, 2021-01-28, 2020-01-03, 2020-01-1...
# ...       ...                                                ...
# 2196       ZM  [2020-03-04, 2021-04-22, 2020-09-04, 2021-09-0...
# 2197     ZNGA               [2021-03-30, 2021-03-26, 2021-03-25]
# 2198     ZOOM               [2021-01-15, 2021-01-15, 2021-01-04]
# 2199      ZTS  [2020-11-25, 2020-11-25, 2020-03-27, 2021-02-1...
# 2200      ZUO   [2019-11-14, 2020-01-27, 2020-09-03, 2020-12-11]
#
#                                              date_q_str
# 0                          ('2021-02-26', '2021-02-26')
# 1                                        ('2021-11-19')
# 2            ('2021-02-16', '2020-04-09', '2021-11-18')
# 3     ('2020-11-17', '2019-12-18', '2022-08-02', '20...
# 4     ('2021-02-17', '2021-01-28', '2020-01-03', '20...
# ...                                                 ...
# 2196  ('2020-03-04', '2021-04-22', '2020-09-04', '20...
# 2197         ('2021-03-30', '2021-03-26', '2021-03-25')
# 2198         ('2021-01-15', '2021-01-15', '2021-01-04')
# 2199  ('2020-11-25', '2020-11-25', '2020-03-27', '20...
# 2200  ('2019-11-14', '2020-01-27', '2020-09-03', '20...
#
# [2201 rows x 3 columns]

# %%
house_dt_tic_grouped["sql"] = v_generate_sql_queries(house_dt_tic_grouped["ticker_q"], house_dt_tic_grouped["date_q_str"])
house_dt_tic_grouped
# Out:
#      ticker_q                                             date_q  \
# 0      35G.SG                           [2021-02-26, 2021-02-26]
# 1         7XY                                       [2021-11-19]
# 2           A               [2021-02-16, 2020-04-09, 2021-11-18]
# 3          AA  [2020-11-17, 2019-12-18, 2022-08-02, 2022-08-0...
# 4       AAGIY  [2021-02-17, 2021-01-28, 2020-01-03, 2020-01-1...
# ...       ...                                                ...
# 2196       ZM  [2020-03-04, 2021-04-22, 2020-09-04, 2021-09-0...
# 2197     ZNGA               [2021-03-30, 2021-03-26, 2021-03-25]
# 2198     ZOOM               [2021-01-15, 2021-01-15, 2021-01-04]
# 2199      ZTS  [2020-11-25, 2020-11-25, 2020-03-27, 2021-02-1...
# 2200      ZUO   [2019-11-14, 2020-01-27, 2020-09-03, 2020-12-11]
#
#                                              date_q_str  \
# 0                          ('2021-02-26', '2021-02-26')
# 1                                        ('2021-11-19')
# 2            ('2021-02-16', '2020-04-09', '2021-11-18')
# 3     ('2020-11-17', '2019-12-18', '2022-08-02', '20...
# 4     ('2021-02-17', '2021-01-28', '2020-01-03', '20...
# ...                                                 ...
# 2196  ('2020-03-04', '2021-04-22', '2020-09-04', '20...
# 2197         ('2021-03-30', '2021-03-26', '2021-03-25')
# 2198         ('2021-01-15', '2021-01-15', '2021-01-04')
# 2199  ('2020-11-25', '2020-11-25', '2020-03-27', '20...
# 2200  ('2019-11-14', '2020-01-27', '2020-09-03', '20...
#
#                                                     sql
# 0     SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 1     SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 2     SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 3     SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 4     SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# ...                                                 ...
# 2196  SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 2197  SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 2198  SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 2199  SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
# 2200  SELECT * FROM crsp.wrds_dsfv2_query WHERE tick...
#
# [2201 rows x 4 columns]

# %%
output = house_dt_tic_grouped[["ticker_q", "sql"]].copy()
output.to_csv("house_sql_queries.csv", index=False)
