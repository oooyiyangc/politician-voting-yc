# %% [markdown]
# # Selection Bias Test

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
pfd = pd.read_csv("../data/pfd_clean/PFD_trans.csv")
pfd
# Out:
# C:\Users\Yiyan\AppData\Local\Temp/ipykernel_34104/4202235598.py:1: DtypeWarning: Columns (3,8,11,13,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   pfd = pd.read_csv("../data/pfd_clean/PFD_trans.csv")
#                 ID Chamber        CID CalendarYear ReportType Asset4SJD  \
# 0       A170015889       s  N00009888           17          Y         S
# 1       A170015888       s  N00009888           17          Y         S
# 2       A170015887       s  N00009888           17          Y         S
# 3       A170015886       s  N00009888           17          Y         S
# 4       A170015885       s  N00009888           17          Y         S
# ...            ...     ...        ...          ...        ...       ...
# 377663  C160015720       s  N00030245           16          A         S
# 377664  C160015719       s  N00030245           16          A         S
# 377665  C160015718       s  N00030245           16          A         S
# 377666  C160015717       s  N00030245           16          A         S
# 377667  C160015716       s  N00030245           16          A         S
#
#                               Asset4Transacted  \
# 0                Tortoise MLP & Pipeline Instl
# 1           Vanguard Dividend Appreciation ETF
# 2            UBS ETRACS Alerian MLP Infras ETN
# 3                Tortoise MLP & Pipeline Instl
# 4       DTC US Active Equity Common Trust Fund
# ...                                        ...
# 377663      Oakmark Equity And Income Investor
# 377664      Oakmark Equity And Income Investor
# 377665                    First Eagle Global I
# 377666                    First Eagle Global I
# 377667                         IVA Worldwide I
#
#                                        Orgname Ultorg RealCode  ...  \
# 0                 Tortoise MLP & Pipeline Fund    NaN      NaN  ...
# 1           Vanguard Dividend Appreciation ETF    NaN      NaN  ...
# 2            UBS ETRACS Alerian MLP Infras ETN    NaN      NaN  ...
# 3                 Tortoise MLP & Pipeline Fund    NaN      NaN  ...
# 4       DTC US Active Equity Common Trust Fund    NaN      NaN  ...
# ...                                        ...    ...      ...  ...
# 377663            Oakmark Equity & Income Fund    NaN      NaN  ...
# 377664            Oakmark Equity & Income Fund    NaN      NaN  ...
# 377665                 First Eagle Global Fund    NaN      NaN  ...
# 377666                 First Eagle Global Fund    NaN      NaN  ...
# 377667                         IVA Worldwide I    NaN      NaN  ...
#
#        Asset4Purchased Asset4Sold Asset4Exchanged Asset4Date Asset4DateText  \
# 0                    x                                   NaN     09/29/2017
# 1                    x                                   NaN     07/19/2017
# 2                    x                                   NaN     07/19/2017
# 3                    x                                   NaN     07/17/2017
# 4                    x                                   NaN     07/07/2017
# ...                ...        ...             ...        ...            ...
# 377663                          x                        NaN     10/31/2016
# 377664                          x                        NaN     03/28/2016
# 377665                          x                        NaN     10/31/2016
# 377666                          x                        NaN     03/28/2016
# 377667                          x                        NaN     10/31/2016
#
#        Asset4TransAmt Asset4ExactAmt CofD      TransNotes Dupe
# 0                  C             NaN                   --    d
# 1                  C             NaN                   --    d
# 2                  C             NaN                   --    d
# 3                  C             NaN                   --    d
# 4                  E             NaN                   --    d
# ...               ...            ...  ...             ...  ...
# 377663             B             NaN          Sale (Full)    d
# 377664             B             NaN       Sale (Partial)    d
# 377665             B             NaN       Sale (Partial)    d
# 377666             B             NaN       Sale (Partial)    d
# 377667             B             NaN       Sale (Partial)    d
#
# [377668 rows x 26 columns]

# %%
crp_id = pd.read_csv("../data/pfd/CRP_IDs.csv")
crp_id
# Out:
#             CID             CRPName Party Office  FECCandID  Congress
# 0     N00035451         Adams, Alma     D   NC12  H4NC12100       117
# 1     N00003028  Aderholt, Robert B     R   AL04  H6AL04098       117
# 2     N00033997       Aguilar, Pete     D   CA31  H2CA31125       117
# 3     N00033720    Allen, Richard W     R   GA12  H2GA12121       117
# 4     N00040989       Allred, Colin     D   TX32  H8TX32098       117
# ...         ...                 ...   ...    ...        ...       ...
# 6593  N00009824           Wu, David     D   OR01  H8OR01072       106
# 6594  N00007724          Wyden, Ron     D   ORS2  S6OR00110       106
# 6595  N00001849      Wynn, Albert R     D   MD04  H2MD05361       106
# 6596  N00001817     Young, C W Bill     R   FL10  H6FL06035       106
# 6597  N00007999          Young, Don     R   AK01  H6AK00045       106
#
# [6598 rows x 6 columns]

# %% [markdown]
# ## Handles duplicates

# %%
crp_id_unique = crp_id[["CID", "FECCandID"]].drop_duplicates()
crp_id_unique
# Out:
#             CID  FECCandID
# 0     N00035451  H4NC12100
# 1     N00003028  H6AL04098
# 2     N00033997  H2CA31125
# 3     N00033720  H2GA12121
# 4     N00040989  H8TX32098
# ...         ...        ...
# 6538  N00005004  H2MO02037
# 6552  N00004572  H6SD00085
# 6567  N00004452  H6MN04103
# 6586  N00000340  S8RI00086
# 6590  N00002181  H2WV03025
#
# [1503 rows x 2 columns]

# %%
len(np.unique(crp_id_unique["CID"]))
# Out:
# 1383

# %%
len(np.unique(crp_id_unique["FECCandID"]))
# Out:
# 1503

# %%
crp_id_unique_grouped = crp_id_unique.groupby("CID").count()
crp_id_dup = np.array(crp_id_unique_grouped[crp_id_unique_grouped["FECCandID"] > 1].index)
len(crp_id_dup)
# Out:
# 120

# %%
pfd_unique = pfd[~pfd["CID"].isin(crp_id_dup)]
pfd_unique.shape
# Out:
# (321148, 26)

# %%
pfd_crpid = pfd_unique.merge(crp_id_unique, on="CID", how="left")
pfd_crpid = pfd_crpid.dropna(subset=["Asset4Transacted"])
pfd_crpid
# Out:
#                 ID Chamber        CID CalendarYear ReportType Asset4SJD  \
# 0       A170015889       s  N00009888           17          Y         S
# 1       A170015888       s  N00009888           17          Y         S
# 2       A170015887       s  N00009888           17          Y         S
# 3       A170015886       s  N00009888           17          Y         S
# 4       A170015885       s  N00009888           17          Y         S
# ...            ...     ...        ...          ...        ...       ...
# 321143  A170015894       s  N00009888           17          Y         S
# 321144  A170015893       s  N00009888           17          Y         S
# 321145  A170015892       s  N00009888           17          Y         S
# 321146  A170015891       s  N00009888           17          Y         S
# 321147  A170015890       s  N00009888           17          Y         S
#
#                                 Asset4Transacted  \
# 0                  Tortoise MLP & Pipeline Instl
# 1             Vanguard Dividend Appreciation ETF
# 2              UBS ETRACS Alerian MLP Infras ETN
# 3                  Tortoise MLP & Pipeline Instl
# 4         DTC US Active Equity Common Trust Fund
# ...                                          ...
# 321143        Vanguard Dividend Appreciation ETF
# 321144         UBS ETRACS Alerian MLP Infras ETN
# 321145               Vanguard 500 Index Investor
# 321146   Vanguard Extended Market Index Investor
# 321147  Loomis Sayles Sr Floating Rate and F/I Y
#
#                                         Orgname Ultorg RealCode  ...  \
# 0                  Tortoise MLP & Pipeline Fund    NaN      NaN  ...
# 1            Vanguard Dividend Appreciation ETF    NaN      NaN  ...
# 2             UBS ETRACS Alerian MLP Infras ETN    NaN      NaN  ...
# 3                  Tortoise MLP & Pipeline Fund    NaN      NaN  ...
# 4        DTC US Active Equity Common Trust Fund    NaN      NaN  ...
# ...                                         ...    ...      ...  ...
# 321143       Vanguard Dividend Appreciation ETF    NaN      NaN  ...
# 321144        UBS ETRACS Alerian MLP Infras ETN    NaN      NaN  ...
# 321145                       Vanguard 500 index    NaN      NaN  ...
# 321146  Vanguard Extended Market Index Investor    NaN      NaN  ...
# 321147   Loomis Sayles Sr Floating Rate & F/I Y    NaN      NaN  ...
#
#        Asset4Sold Asset4Exchanged Asset4Date Asset4DateText Asset4TransAmt  \
# 0                                        NaN     09/29/2017             C
# 1                                        NaN     07/19/2017             C
# 2                                        NaN     07/19/2017             C
# 3                                        NaN     07/17/2017             C
# 4                                        NaN     07/07/2017             E
# ...           ...             ...        ...            ...            ...
# 321143                                   NaN     10/02/2017             C
# 321144                                   NaN     10/02/2017             B
# 321145                                   NaN     09/29/2017             D
# 321146                                   NaN     09/29/2017             C
# 321147                                   NaN     09/29/2017             B
#
#        Asset4ExactAmt CofD TransNotes Dupe  FECCandID
# 0                 NaN              --    d  S2TN00058
# 1                 NaN              --    d  S2TN00058
# 2                 NaN              --    d  S2TN00058
# 3                 NaN              --    d  S2TN00058
# 4                 NaN              --    d  S2TN00058
# ...               ...  ...        ...  ...        ...
# 321143            NaN              --    d  S2TN00058
# 321144            NaN              --    d  S2TN00058
# 321145            NaN              --    d  S2TN00058
# 321146            NaN              --    d  S2TN00058
# 321147            NaN              --    d  S2TN00058
#
# [316699 rows x 27 columns]

# %%
pfd_etf = pfd_crpid[pfd_crpid["Asset4Transacted"].str.contains("ETF")]
pfd_etf
# Out:
#                 ID Chamber        CID CalendarYear ReportType Asset4SJD  \
# 1       A170015888       s  N00009888           17          Y         S
# 122     A170017845       s  N00000491           17          Y         S
# 132     A180017835       s  N00000491           18          Y         S
# 134     A180017090       s  N00036915           18          Y         S
# 135     A180017089       s  N00036915           18          Y         S
# ...            ...     ...        ...          ...        ...       ...
# 321122  A170019005       s  N00036915           17          A         S
# 321123  A170019004       s  N00036915           17          A         S
# 321124  A170019003       s  N00036915           17          A         S
# 321129  A170015908       s  N00009888           17          Y         S
# 321143  A170015894       s  N00009888           17          Y         S
#
#                                          Asset4Transacted  \
# 1                      Vanguard Dividend Appreciation ETF
# 122                       Vanguard FTSE All-Wld ex-US ETF
# 132     Vanguard FTSE All-World ex-US Index Fund ETF S...
# 134                            iShares Core MSCI EAFE ETF
# 135           Invesco Emerging Markets Sovereign Debt ETF
# ...                                                   ...
# 321122                       Vanguard Short-Term Bond ETF
# 321123              VanEck Vectors JP Morgan EM LC Bd ETF
# 321124             iShares Core MSCI Emerging Markets ETF
# 321129                 Vanguard Dividend Appreciation ETF
# 321143                 Vanguard Dividend Appreciation ETF
#
#                                                   Orgname Ultorg RealCode  \
# 1                      Vanguard Dividend Appreciation ETF    NaN      NaN
# 122                       Vanguard FTSE All-Wld ex-US ETF    NaN      NaN
# 132     Vanguard FTSE All-World ex-US Index Fund ETF S...    NaN      NaN
# 134                            iShares Core MSCI EAFE ETF    NaN      NaN
# 135           Invesco Emerging Markets Sovereign Debt ETF    NaN      NaN
# ...                                                   ...    ...      ...
# 321122                       Vanguard Short Term Bond ETF    NaN      NaN
# 321123              VanEck Vectors JP Morgan EM LC Bd ETF    NaN      NaN
# 321124                  iShares MSCI Emerging Markets ETF    NaN      NaN
# 321129                 Vanguard Dividend Appreciation ETF    NaN      NaN
# 321143                 Vanguard Dividend Appreciation ETF    NaN      NaN
#
#         ... Asset4Sold Asset4Exchanged  Asset4Date Asset4DateText  \
# 1       ...                                    NaN     07/19/2017
# 122     ...                                    NaN     06/15/2017
# 132     ...                             01/29/2018     01/29/2018
# 134     ...          x                  06/20/2018     06/20/2018
# 135     ...          x                  06/20/2018     06/20/2018
# ...     ...        ...             ...         ...            ...
# 321122  ...          x                         NaN     04/28/2017
# 321123  ...          x                         NaN     04/28/2017
# 321124  ...          x                         NaN     04/28/2017
# 321129  ...          x                         NaN     03/02/2017
# 321143  ...                                    NaN     10/02/2017
#
#        Asset4TransAmt Asset4ExactAmt CofD      TransNotes Dupe  FECCandID
# 1                  C             NaN                   --    d  S2TN00058
# 122                B             NaN                   --       S6ME00159
# 132                C             NaN                   --       S6ME00159
# 134                B             NaN       Sale (Partial)    d  S6CA00584
# 135                B             NaN       Sale (Partial)    d  S6CA00584
# ...               ...            ...  ...             ...  ...        ...
# 321122             B             NaN          Sale (Full)       S6CA00584
# 321123             B             NaN          Sale (Full)       S6CA00584
# 321124             C             NaN          Sale (Full)       S6CA00584
# 321129             C             NaN       Sale (Partial)    d  S2TN00058
# 321143             C             NaN                   --    d  S2TN00058
#
# [9324 rows x 27 columns]

# %%
pfd_etf_individuals = pfd_etf[["CID", "FECCandID"]].drop_duplicates()
pfd_etf_individuals
# Out:
#               CID  FECCandID
# 1       N00009888  S2TN00058
# 122     N00000491  S6ME00159
# 134     N00036915  S6CA00584
# 186     N00012508  S8DE00079
# 522     N00001758  S0IA00028
# ...           ...        ...
# 287800  N00030602  H2TX33040
# 287999  N00038285  H6TX19099
# 288254  N00036154  H4NJ01084
# 290270  N00001692  H0DC00058
# 290474  N00000751  H6NJ08118
#
# [213 rows x 2 columns]

# %%
pfd_etf_individuals.to_csv("../data/pfd_clean/pfd_etf_individuals.csv", index=False)

# %% [markdown]
# ## Selected Keywords

# %%
pfd_etf[pfd_etf["Asset4Transacted"].str.contains("Clean")]
# Out:
#                ID Chamber        CID CalendarYear ReportType Asset4SJD  \
# 12870  E140076861       H  N00033030           14          Y
# 12871  E140076860       H  N00033030           14          Y
#
#                                         Asset4Transacted  \
# 12870  Jared's Fidelity Rollover IRA Powershares Wild...
# 12871  Jared's Fidelity Rollover IRA Powershares Wild...
#
#                              Orgname Ultorg RealCode  ... Asset4Sold  \
# 12870  Jared's Fidelity Rollover IRA    NaN      NaN  ...
# 12871  Jared's Fidelity Rollover IRA    NaN      NaN  ...
#
#       Asset4Exchanged  Asset4Date Asset4DateText Asset4TransAmt  \
# 12870                  03/03/2014         140303             B
# 12871                  03/27/2014         140327             B
#
#       Asset4ExactAmt CofD TransNotes Dupe  FECCandID
# 12870            NaN             NaN       H2CA06259
# 12871            NaN             NaN       H2CA06259
#
# [2 rows x 27 columns]

# %%
pfd_etf[pfd_etf["Asset4Transacted"].str.contains("Sustainable")]
# Out:
# Empty DataFrame
# Columns: [ID, Chamber, CID, CalendarYear, ReportType, Asset4SJD, Asset4Transacted, Orgname, Ultorg, RealCode, Source, Asset4Descrip, Orgname2, Ultorg2, RealCode2, Source2, Asset4Purchased, Asset4Sold, Asset4Exchanged, Asset4Date, Asset4DateText, Asset4TransAmt, Asset4ExactAmt, CofD, TransNotes, Dupe, FECCandID]
# Index: []
#
# [0 rows x 27 columns]

# %%
pfd_etf[pfd_etf["Asset4Transacted"].str.contains("Solar")]
# Out:
#                ID Chamber        CID CalendarYear ReportType Asset4SJD  \
# 4681   B160004377       S  N00027533           16          Y         J
# 45931  A130037558       H  N00006008           13          Y         D
# 45932  A130037557       H  N00006008           13          Y         D
# 56277  E150020371       s  N00027533           15          A         J
# 57262  E150018897       s  N00027533           15          Y         J
#
#                          Asset4Transacted               Orgname Ultorg  \
# 4681                 Guggenheim Solar ETF  Guggenheim Solar ETF    NaN
# 45931  Kaitlin Guggenheim Solar ETF (TAN)               Kaitlin    NaN
# 45932  Kaitlin Guggenheim Solar ETF (TAN)               Kaitlin    NaN
# 56277                Guggenheim Solar ETF  Guggenheim Solar ETF    NaN
# 57262                Guggenheim Solar ETF  Guggenheim Solar ETF    NaN
#
#       RealCode  ... Asset4Sold Asset4Exchanged  Asset4Date Asset4DateText  \
# 4681       NaN  ...          x                         NaN     04/12/2016
# 45931      NaN  ...          X                  10/29/2013         131029
# 45932      NaN  ...                             10/22/2013         131022
# 56277      NaN  ...                             11/25/2015     11/25/2015
# 57262      NaN  ...                             11/25/2015     11/25/2015
#
#       Asset4TransAmt Asset4ExactAmt CofD   TransNotes Dupe  FECCandID
# 4681              B             NaN       Sale (Full)       S6RI00221
# 45931             B             NaN               NaN       H6TX15055
# 45932             B             NaN               NaN       H6TX15055
# 56277             C             NaN                --       S6RI00221
# 57262             C             NaN                --       S6RI00221
#
# [5 rows x 27 columns]

# %%
pfd_etf[pfd_etf["Asset4Transacted"].str.contains("Energy")]
# Out:
#                 ID Chamber        CID CalendarYear ReportType Asset4SJD  \
# 633     A170016584       s  N00033054           17          Y
# 716     A170016500       s  N00033054           17          A
# 740     A170016476       s  N00033054           17          A         J
# 883     A170017281       s  N00033054           17          Y
# 921     A180017197       s  N00033177           18          Y
# ...            ...     ...        ...          ...        ...       ...
# 320831  A180019296       s  N00038397           18          Y
# 320862  A180019268       s  N00038397           18          Y         S
# 320866  A180019264       s  N00038397           18          Y         S
# 320867  A180019263       s  N00038397           18          Y         S
# 320868  A180019262       s  N00038397           18          Y         S
#
#                              Asset4Transacted                        Orgname  \
# 633             Energy Select Sector SPDR ETF  Energy Select Sector SPDR ETF
# 716             Energy Select Sector SPDR ETF  Energy Select Sector SPDR ETF
# 740             Energy Select Sector SPDR ETF  Energy Select Sector SPDR ETF
# 883             Energy Select Sector SPDR ETF  Energy Select Sector SPDR ETF
# 921     Vanguard Energy Index Fund ETF Shares     Vanguard Energy Index Fund
# ...                                       ...                            ...
# 320831              iShares Global Energy ETF      iShares Global Energy ETF
# 320862                iShares U.S. Energy ETF          iShares US Energy ETF
# 320866                iShares U.S. Energy ETF          iShares US Energy ETF
# 320867                iShares U.S. Energy ETF          iShares US Energy ETF
# 320868              iShares Global Energy ETF      iShares Global Energy ETF
#
#        Ultorg RealCode  ... Asset4Sold Asset4Exchanged  Asset4Date  \
# 633       NaN      NaN  ...                                    NaN
# 716       NaN      NaN  ...                                    NaN
# 740       NaN      NaN  ...          x                         NaN
# 883       NaN      NaN  ...          x                         NaN
# 921       NaN      NaN  ...          x                  01/12/2018
# ...       ...      ...  ...        ...             ...         ...
# 320831    NaN      NaN  ...                             03/14/2018
# 320862    NaN      NaN  ...                             08/29/2018
# 320866    NaN      NaN  ...                             08/06/2018
# 320867    NaN      NaN  ...                             07/05/2018
# 320868    NaN      NaN  ...                             07/05/2018
#
#        Asset4DateText Asset4TransAmt Asset4ExactAmt CofD      TransNotes Dupe  \
# 633        07/17/2017             B             NaN                   --    d
# 716        07/17/2017             B             NaN                   --    d
# 740        07/17/2017             B             NaN          Sale (Full)    d
# 883        07/17/2017             B             NaN          Sale (Full)
# 921        01/12/2018             C             NaN       Sale (Partial)    d
# ...               ...            ...            ...  ...             ...  ...
# 320831     03/14/2018             B             NaN                   --
# 320862     08/29/2018             B             NaN                   --
# 320866     08/06/2018             B             NaN                   --
# 320867     07/05/2018             B             NaN                   --
# 320868     07/05/2018             C             NaN                   --
#
#         FECCandID
# 633     S2MT00096
# 716     S2MT00096
# 740     S2MT00096
# 883     S2MT00096
# 921     S2VA00142
# ...           ...
# 320831  S6NH00091
# 320862  S6NH00091
# 320866  S6NH00091
# 320867  S6NH00091
# 320868  S6NH00091
#
# [147 rows x 27 columns]

# %%
pfd_etf[pfd_etf["Asset4Transacted"].str.contains("Green")]
# Out:
# Empty DataFrame
# Columns: [ID, Chamber, CID, CalendarYear, ReportType, Asset4SJD, Asset4Transacted, Orgname, Ultorg, RealCode, Source, Asset4Descrip, Orgname2, Ultorg2, RealCode2, Source2, Asset4Purchased, Asset4Sold, Asset4Exchanged, Asset4Date, Asset4DateText, Asset4TransAmt, Asset4ExactAmt, CofD, TransNotes, Dupe, FECCandID]
# Index: []
#
# [0 rows x 27 columns]
