# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# set the max columns to none
pd.set_option('display.max_columns', None)

# %%
data = pd.read_stata("../data/sacerdote/house_senate_merged_dataset.dta")
data
# Out:
# C:\Users\Yiyan\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\stata.py:1457: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   warnings.warn(msg, UnicodeWarning)
#                            Model ticker              uid    evtdate  \
# 0      Fama-French Plus Momentum   CBNK  91397-03JAN2012 2012-01-03
# 1      Fama-French Plus Momentum    OPY  78451-03JAN2012 2012-01-03
# 2      Fama-French Plus Momentum    STZ  64899-03JAN2012 2012-01-03
# 3      Fama-French Plus Momentum    HON  10145-03JAN2012 2012-01-03
# 4      Fama-French Plus Momentum   NUAN  82759-03JAN2012 2012-01-03
# ...                          ...    ...              ...        ...
# 50600                             BRK.B                  2020-12-24
# ...

# %%
plt.hist(data["date"], bins=10);
